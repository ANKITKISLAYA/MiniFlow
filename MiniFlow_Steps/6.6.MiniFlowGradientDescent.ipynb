# %% [markdown]
# # Demonstration of working of gradient descent on our cost function

# %% [markdown]
# # Gradient Descent formula
# ![image.png](attachment:29bf3715-af2a-4ff6-a501-aecf36cc1181.png)

# %%
def gradient_descent_update(x, gradx, learning_rate):
    """
    Performs a gradient descent update.
    """
    # TODO: Implement gradient descent.
    
    # Return the new value for x
    x = x - learning_rate * gradx
    return x



"""
Given the starting point of any `x` gradient descent
should be able to find the minimum value of x for the
cost function `f` defined below.
"""
import random
#from gd import gradient_descent_update


def f(x):
    """
    Quadratic function.

    It's easy to see the minimum value of the function
    is 5 when is x=0.
    """
    return x**2 + 5


def df(x):
    """
    Derivative of `f` with respect to `x`.
    """
    return 2*x


# Random number between 0 and 10,000. Feel free to set x whatever you like.
x = random.randint(0, 10000)
# Set the learning rate
learning_rate = 0.1
epochs = 100

for i in range(epochs+1):
    cost = f(x)
    gradx = df(x)
    print("EPOCH {}: Cost = {:.3f}, x = {:.3f}".format(i, cost, gradx))
    x = gradient_descent_update(x, gradx, learning_rate)
# Out:
# EPOCH 0: Cost = 13155134.000, x = 7254.000
# EPOCH 1: Cost = 8419287.560, x = 5803.200
# EPOCH 2: Cost = 5388345.838, x = 4642.560
# EPOCH 3: Cost = 3448543.137, x = 3714.048
# EPOCH 4: Cost = 2207069.407, x = 2971.238
# EPOCH 5: Cost = 1412526.221, x = 2376.991
# EPOCH 6: Cost = 904018.581, x = 1901.593
# EPOCH 7: Cost = 578573.692, x = 1521.274
# EPOCH 8: Cost = 370288.963, x = 1217.019
# EPOCH 9: Cost = 236986.736, x = 973.615
# EPOCH 10: Cost = 151673.311, x = 778.892
# EPOCH 11: Cost = 97072.719, x = 623.114
# EPOCH 12: Cost = 62128.340, x = 498.491
# EPOCH 13: Cost = 39763.938, x = 398.793
# EPOCH 14: Cost = 25450.720, x = 319.034
# EPOCH 15: Cost = 16290.261, x = 255.227
# EPOCH 16: Cost = 10427.567, x = 204.182
# EPOCH 17: Cost = 6675.443, x = 163.346
# EPOCH 18: Cost = 4274.083, x = 130.676
# EPOCH 19: Cost = 2737.213, x = 104.541
# EPOCH 20: Cost = 1753.617, x = 83.633
# EPOCH 21: Cost = 1124.115, x = 66.906
# EPOCH 22: Cost = 721.233, x = 53.525
# ...
